# %% [markdown]
# <a href="https://colab.research.google.com/github/M-DaniyalHS1/Dani.py/blob/main/countdown_timer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing module
import time
# creating a function
def countdown(t):
    # creating a while loop
    while t:
     mins,secs = divmod(t,60)
     timer = f'{mins:02d}:{secs:02d}'
     # printing time
     print(timer,end = '\r')
     time.sleep(1)
     t -= 1
    print('Time finished.....')
    # prompting user to enter seconds to countdown
t = int(input('Enter the time in seconds: '))
countdown(t)
# Out:
# Enter the time in seconds: 4
# Time finished.....
